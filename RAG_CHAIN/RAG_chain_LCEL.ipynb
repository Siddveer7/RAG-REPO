# %%
### Create a RAG chain using LCEL (Langchain expression language)

from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough,RunnableParallel

# %%
from langchain_core.prompts import ChatPromptTemplate

custom_prompt = ChatPromptTemplate.from_template(""" use the following context to answer the question at the end.
If you don't know the answer, just say that you don't know, don't try to make up an answer.
context: {context}
question: {question}
answer in detail:""")
custom_prompt
# Out:
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template=" use the following context to answer the question at the end.\nIf you don't know the answer, just say that you don't know, don't try to make up an answer.\ncontext: {context}\nquestion: {question}\nanswer in detail:"), additional_kwargs={})])

# %%
## Format the output documents for the prompt
def format_docs(docs):
    return "\n\n".join([doc.page_content for doc in docs])

# %%
## build the chain using LCEL 

rag_chain_lcel = ( {"context": retriver| format_docs,"question": RunnablePassthrough()}
| custom_prompt | llm | StrOutputParser())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 ## build the chain using LCEL
# ----> 3 rag_chain_lcel = ( {"context": retriver| format_docs,"question": RunnablePassthrough()}
#       4 | custom_prompt | llm | StrOutputParser())
#
# NameError: name 'retriver' is not defined

# %%
response= rag_chain_lcel.invoke("What are the types of Machine Learning?")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 response= rag_chain_lcel.invoke("What are the types of Machine Learning?")
#
# NameError: name 'rag_chain_lcel' is not defined

# %%
# query using the LCEL approch

def query_rag(question):
    print(f"question:{question}")
    print("_"*50)

    #method 
    answer = rag_chain_lcel.invoke(question)
    print(f"Answer:{answer}")

    # get source douments separetly if needed 
    docs = retriver.get_revelent_documents(question)
    print(f"source documents:{docs}")
    for i,doc in enumerate(docs):
        print(f"source document {i}:{doc.page_content}")

# %%
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings

# Initialize embeddings and vector store
embeddings = OpenAIEmbeddings()
vector_store = Chroma(embedding_function=embeddings)
# Out:
# C:\Users\siddv\AppData\Local\Temp\ipykernel_144\3873746666.py:6: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vector_store = Chroma(embedding_function=embeddings)

# %%
newchunks = text_splitter.split_documents([new_file])
vector_store.add_documents(newchunks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 newchunks = text_splitter.split_documents([new_file])
#       2 vector_store.add_documents(newchunks)
#
# NameError: name 'text_splitter' is not defined

# %%
from langchain_core.documents import Document

new_doc = Document(page_content="Reinforcement Learning is a type of Machine Learning where an agent learns to make decisions by taking actions in an environment to maximize some notion of cumulative reward.", metadata={"source": "reinforcement_learning.txt"} )

# %%
vector_store.add_documents([new_doc])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 vector_store.add_documents([new_doc])
#
# File d:\RAG\.venv\Lib\site-packages\langchain_core\vectorstores\base.py:288, in VectorStore.add_documents(self, documents, **kwargs)
#     286     texts = [doc.page_content for doc in documents]
#     287     metadatas = [doc.metadata for doc in documents]
# --> 288     return self.add_texts(texts, metadatas, **kwargs)
#     289 msg = (
#     290     f"`add_documents` and `add_texts` has not been implemented "
#     291     f"for {self.__class__.__name__} "
#     292 )
#     293 raise NotImplementedError(msg)
#
# File d:\RAG\.venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:277, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     275 texts = list(texts)
#     276 if self._embedding_function is not None:
# ...
