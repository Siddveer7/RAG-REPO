# %%
from langchain.chains import create_history_aware_retriever
from langchain_core.prompts import MessagesPlaceholder
from langchain_core.messages import HumanMessage,AIMessage

# %%
from langchain.prompts import ChatPromptTemplate

contextualize_q_system_prompt = """You are a helpful AI assistant that helps people find information. You are given the following extracted parts of a long document and a question. Provide a conversational answer based on the context provided.
If you don't know the answer, just say that you don't know, don't   make up an answer.use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't make up an answer.DO not repeat the context in your answer.
Use three sentences maximum."""

contextualize_q_human_prompt = ChatPromptTemplate.from_messages([
    ("system",contextualize_q_system_prompt),
    MessagesPlaceholder("chat_history"),
    ("human","{input}"),
])

# %%
### Cerate history aware retriver 

history_Aware_retriver = create_history_aware_retriever(llm, retriver, contextualize_q_system_prompt)

history_Aware_retriver
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 ### Cerate history aware retriver
# ----> 3 history_Aware_retriver = create_history_aware_retriever(llm, retriver, contextualize_q_system_prompt)
#       5 history_Aware_retriver
#
# NameError: name 'llm' is not defined
